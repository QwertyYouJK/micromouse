# %% [markdown]
# ### Task 0
#
# Print Hello world to the terminal

# %%
# Put your solution in this box and run the program

# %% [markdown]
# ### Task 1 - Load an Image
#
# Load in the "shapes.png" image and display it using matplotlib.
#
# Ensure the colours are correctly displayed in RGB. [Hint](https://docs.opencv.org/4.x/d8/d01/group__imgproc__color__conversions.html#ga4e0972be5de079fed4e3a10e24ef5ef0)

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

IMAGE_FILE = "shapes.png"

# %% [markdown]
# ### Task 2 - Colour Mask
#
# Using a blue color mask, generate a monochrome mask of the blue shapes.
#
# You will need to use the cv2.inRange() function.
#
# Hint: ([0,0,90] and [150,180,255])

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

IMAGE_FILE = "shapes.png"
img = cv2.imread(IMAGE_FILE)
rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
lower = np.array([0, 0, 90])
upper = np.array([150, 180, 255])
blue_mask = cv2.inRange(rgb, lower, upper)

# %% [markdown]
# ### Task 3 - Bitwise Operation
#
# Using the bitwise and operation, apply the mask to the source image and display the result.
#
# Examples for cv2.bitwise_and can be found [Here](https://www.geeksforgeeks.org/arithmetic-operations-on-images-using-opencv-set-2-bitwise-operations-on-binary-images/)

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

IMAGE_FILE = "shapes.png"
img = cv2.imread(IMAGE_FILE)
rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
lower = np.array([0, 0, 90])
upper = np.array([150, 180, 255])
blue_mask = cv2.inRange(rgb, lower, upper)
blue = cv2.bitwise_and(rgb, rgb, mask=blue_mask)
plt.imshow(blue)
plt.show()

# %% [markdown]
# ### Task 4 - HSV and Maze
#
# HSV (Hue, Saturation, Value) may provide better results for the Micromouse maze.
#
# Use the provided "hsv_picker.ipynb" to find a good range of HSV values for the maze and display the resulting mask of the maze walls.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

IMAGE_FILE = "maze.jpg"
img = cv2.imread(IMAGE_FILE)

width = img.shape[1] // 4
height = img.shape[0] // 4
img = cv2.resize(img, (width, height), interpolation=cv2.INTER_AREA)

HSV_img = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
lower = np.array([13, 16, 85], np.uint8)
upper = np.array([76, 255, 255], np.uint8)
maze_mask = cv2.inRange(HSV_img, lower, upper)
cv2.imshow('maze mask', maze_mask)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ### Task 5 - Erode
#
# Perform an erode operation from the source image. Use a kernel size of 7 and perform 5 iterations.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

IMAGE_FILE = "maze.jpg"
img = cv2.imread(IMAGE_FILE)

width = img.shape[1] // 4
height = img.shape[0] // 4
img = cv2.resize(img, (width, height), interpolation=cv2.INTER_AREA)

HSV_img = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
lower = np.array([13, 16, 85], np.uint8)
upper = np.array([76, 255, 255], np.uint8)
maze_mask = cv2.inRange(HSV_img, lower, upper)

kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (7, 7))
erosion = cv2.erode(maze_mask, kernel, iterations = 1)
cv2.imshow('erosion', erosion)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ### Task 6 - Dilate
#
# Perform an dilate operation from the source image. Use a kernel size of 3 and perform 5 iterations.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

IMAGE_FILE = "maze.jpg"
img = cv2.imread(IMAGE_FILE)

width = img.shape[1] // 4
height = img.shape[0] // 4
img = cv2.resize(img, (width, height), interpolation=cv2.INTER_AREA)

HSV_img = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
lower = np.array([13, 16, 85], np.uint8)
upper = np.array([76, 255, 255], np.uint8)
maze_mask = cv2.inRange(HSV_img, lower, upper)

kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (3, 3))
dilation = cv2.dilate(maze_mask, kernel, iterations = 1)
cv2.imshow('dilation', dilation)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ### Task 7 - ASCII representation
#
# Note: This task should be completed as it is part of the Micromouse assignment
#
# Convert the maze into an ASCII representation shown in the lab document. You may need to perform a series of erosions and dilations to get a good mask.
#
# Hint: Write a generic function to sample pixels between two coordinates.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

IMAGE_FILE = "maze.jpg"
img = cv2.imread(IMAGE_FILE)

width = img.shape[1] // 4
height = img.shape[0] // 4
img = cv2.resize(img, (width, height), interpolation=cv2.INTER_AREA)

HSV_img = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
lower = np.array([13, 16, 85], np.uint8)
upper = np.array([76, 255, 255], np.uint8)
maze_mask = cv2.inRange(HSV_img, lower, upper)

kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (7, 7))
morph1 = cv2.morphologyEx(maze_mask, cv2.MORPH_OPEN, kernel)
cv2.imshow('opening morph', morph1)
cv2.waitKey(0)
cv2.destroyAllWindows()
# cv2.imwrite('mask.jpg', morph1)

# # check horizontal walls
# rows = np.zeros((4,9))
# x_coords = [60, 120, 180, 240, 300, 360, 420, 480, 540]
# y_coords = [[110, 120], [170, 180], [230, 240], [290, 300]]
# for i, x in enumerate(x_coords):
#     for j, (y0, y1) in enumerate(y_coords):
#         val = morph1[y0:y1, x]
#         rows[j, i] = np.any(val == 0)

# rows = np.append(rows, np.ones((1, 9)), axis = 0)


# # check vertical walls
# cols = np.zeros((5, 8))
# x_coords = [(80, 90), (140, 150), (210, 220), (270, 280), (330, 340), (380, 390), (440, 450), (510, 520)]
# y_coords = [85, 145, 205, 270, 330]
# for i, (x0, x1) in enumerate(x_coords):
#     for j, y in enumerate(y_coords):
#         val = morph1[y, x0:x1]
#         cols[j, i] = np.any(val == 0)


# cols = np.append(cols, np.ones((cols.shape[0], 1)), axis = 1)
# #print(cols)

# # print ASCII representation
# print(" _ _ _ _ _ _ _ _ _ ")
# for i in range(0, 5):
#     s = "|"
#     for j in range(0, 9):
#         if rows[i, j] == 1:
#             s = s + '_'
#         else:
#             s = s + ' '
            
#         if cols[i, j] == 1:
#             s = s + '|'
#         else:
#             s = s + ' '
#     print(s)
# Out:
#  _ _ _ _ _ _ _ _ _
# |_          |  _  |
# |_ _ _ _ _|_| | | |
# |_ _  |    _|_ _|_|
# |  _  | |_| |     |
# |_ _ _|_ _ _|_ _ _|

# %%
rows:
x = 60, 120, 180, 240, 300, 360, 420, 480, 540
y = [(110, 120), (170, 180), (230, 240), (290, 300)]

cols:
x = [80, 90], [140, 150], [210, 220], [270, 280], [330, 340], [380, 390], [440, 450], [510, 520]
y = 85, 145, 205, 270, 330
# Out:
#   File "<ipython-input-2-c1de0fcfd608>", line 1
#     rows:
#          ^
# SyntaxError: invalid syntax
